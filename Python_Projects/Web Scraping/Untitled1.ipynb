# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get("http://graphics.wsj.com/billion-dollar-club/")
c=r.content

# %%
soup=BeautifulSoup(c,"html.parser")
print(soup.prettify())
# Out:
# <!-- Alternative Masthead Branding -->
# <!--URI: /billion-dollar-club/-->
# <!--EnvironmentName: billion-dollar-club-->
# <!-- Premium Name: modern-->
# <!--Project slug: billion-dollar-club-->
# <!--Environment: -->
# <!--Premium: -->
# <!--Deployed slug: billion-dollar-club-->
# <!-- VERSION c1c4693 -->
# <!DOCTYPE html>
# <!--[if lt IE 7 ]>
# <html lang="en" class="no-js ie6">
# <![endif]-->
# <!--[if IE 7 ]>
# <html lang="en" class="no-js ie7">
# <![endif]-->
# <!--[if IE 8 ]>
# <html lang="en" class="no-js ie8">
# <![endif]-->
# <!--[if IE 9 ]>
# <html lang="en" class="no-js ie9">
# <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    The Billion Dollar Startup Club - WSJ.com
#   </title>
#   <link href="//si.wsj.net/favicon.ico" rel="shortcut icon"/>
# ...

# %%
all=soup.find_all("table",{"class":"table dt-bootstrap no-footer table-condensed table-hover dataTable"})
all[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-8a1d3b10a069> in <module>()
#       1 all=soup.find_all("table",{"class":"table dt-bootstrap no-footer table-condensed table-hover dataTable"})
# ----> 2 all[0]
#
# IndexError: list index out of range

# %%
all[0].find_all("table")[0].text
# Out:
# ''
